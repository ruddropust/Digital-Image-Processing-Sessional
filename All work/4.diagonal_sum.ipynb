# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
img= cv.imread("cat1.jpg") 
img = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
plt.imshow(img, cmap='gray')
plt.axis('off')
plt.show()

# %%
def get_diagonal_sum(img):
    diagonal_1 = np.trace(img)
    diagonal_2 = np.trace(np.fliplr(img))
    print("Dioagonal 1: ", diagonal_1, "Diagonal 2: ", diagonal_2)
    diagonal_sum = diagonal_1 + diagonal_2 - img[img.shape[0]//2, img.shape[1]//2]
    return diagonal_sum

get_diagonal_sum(img)
print(get_diagonal_sum(img))
img[img.shape[0]//2, img.shape[1]//2] = get_diagonal_sum(img)
plt.imshow(img,cmap='gray')
plt.axis('off')
# Out:
# Dioagonal 1:  33650 Diagonal 2:  49375
# Dioagonal 1:  33650 Diagonal 2:  49375
# 82908
# Dioagonal 1:  33650 Diagonal 2:  49375
# (-0.5, 374.5, 499.5, -0.5)

# %%
#without using numpy functions
def get_diagonal_sum(img):
    diag_1=diag_2=0
    for i in range(img.shape[0]):
        for j in range(img.shape[1]):
            if i == j:
                diag_1 += img[i, j]
            if i + j == img.shape[0] - 1:
                diag_2 += img[i, j]
    diag_sum = diag_1 + diag_2 - img[img.shape[0]//2, img.shape[1]//2]
    print("Dioagonal 1: ", diag_1, "Diagonal 2: ", diag_2)
    return diag_sum

get_diagonal_sum(img)
print  (get_diagonal_sum(img))
img[img.shape[0]//2, img.shape[1]//2] = get_diagonal_sum(img)
plt.imshow(img,cmap='gray')
plt.axis('off')
# Out:
# Dioagonal 1:  33650 Diagonal 2:  49857
# Dioagonal 1:  33650 Diagonal 2:  49857
# 83287
# Dioagonal 1:  33650 Diagonal 2:  49857
# (-0.5, 374.5, 499.5, -0.5)
